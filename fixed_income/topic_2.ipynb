# %% [markdown]
# # Topic_2

# %% [markdown]
# ### Bond Pricing Strategy
# * Bond Pricing is a 2 step Process
#     * **Step 1**: find the cash flows the bondholder is entitled to
#     * **Step 2** : find the bond price as the discounted value fo the cash-flows
#
# #### Step 1: ####
# * Ex: Gov of Canada bond issued in the domestic market pays one-half of its coupon rate times its principal value every 6 months up to and including the maturity date
# * Thus: a bond with an **8% coupon and \$5000 face value** maturing on Dec 1, 2005 will make future coupon payments of **4% of principal value every 6 months**
# * That is **$200** on each June 1 and Dec 1 between the purchase date and the maturity date
#
# #### Step 2: ####
# * Discounting:
#     * Time value of money: Dollar today is worth more than a dollar tomorrow
#     * Specifying interest rate is not enough
# * We need:
#     * Maturity
#     * Freq of interest payments
#     * Date of interest rates payment (beginning or end of periods)
# * Basic Formula:
#     * After 1 period, capital is $ C_1 = C_0(1 + r) $
#     * After n period, capital is $ C_n = C_0(1 + r)^n $
#     * Interests : $ I = C_n - C_0 $
# * Ex: Invest \$10,000 for 3 years at 6% with annual compounding
# * Obtain $C_6 = 10,000(1+0.06) ^ 6 = \$11,910 $
# * Interest = \$1,910

# %% [markdown]
# ### Bond Pricing Formula: Geometric Series
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Example: ####
# * Consider a bond with 5% coupon rate
#     * 10 yr maturity
#     * \$1,000 face value
#     * All discount rates equal to 6%
# * Present value
# ![image.png](attachment:image.png)
#
# * Could have guessed bond was below par bc discount rate > coupon
# * If rates decrease to 5%, bond will be at par (1000)

# %% [markdown]
# ### Yield to Maturity
# * Interest rate that makes the present value of the bond's payments equal to its price
# * Its the solution to:
#     ![image.png](attachment:image.png)
# * YTM is the total return anticipated on a bond if bond is held until it matures
# * Expressed as annual rate

# %% [markdown]
# ### Par Yield
# * Coupon rate that causes the bond price to equal its face value
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
